# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("../output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0       chonchi -42.6128  -73.8092      7.29        85           0
# 1        1  longyearbyen  78.2186   15.6401     -8.09        67          75
# 2        2     iskateley  67.6803   53.1512    -16.10        92          32
# 3        3      cidreira -30.1811  -50.2056     21.27        88         100
# 4        4    georgetown   5.4112  100.3354     33.96        62          20
#
#    Wind Speed Country        Date
# 0        0.59      CL  1712992197
# 1       10.29      SJ  1712992198
# 2        6.71      RU  1712992198
# 3        9.53      BR  1712992198
# 4        5.14      MY  1712992198

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map1 = city_data_df.hvplot.points("Lng", "Lat", geo=True, tiles="OSM", size="Humidity", color="City", hover_cols=["City", "Humidity"], frame_height=400, frame_width=600)
    

# Display the map
map1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_weather_df = city_data_df.loc[(city_data_df["Max Temp"]>15) & (city_data_df["Max Temp"]<25) & (city_data_df["Cloudiness"]<80) & (city_data_df["Humidity"]<65) & (city_data_df["Wind Speed"]<10)]

# Drop any rows with null values
ideal_weather_df = ideal_weather_df.dropna()

# Display sample data
ideal_weather_df.head()
# Out:
#     City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 7         7  margaret river -33.9500  115.0667     20.49        60
# 30       30          koster -25.8630   26.8976     15.02        57
# 45       45    port lincoln -34.7333  135.8667     16.55        56
# 51       51     sangsong-ni  39.1694  126.8856     23.41        29
# 77       77         awjilah  29.1081   21.2869     24.46        15
#
#     Cloudiness  Wind Speed Country        Date
# 7           35        2.88      AU  1712992200
# 30           0        4.89      ZA  1712992211
# 45           0        3.81      AU  1712992218
# 51           0        3.90      KP  1712992222
# 77           0        5.12      LY  1712992232

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df = hotel_df.assign(Hotel_Name='')

# Display sample data
hotel_df.head()
# Out:
#               City Country      Lat       Lng  Humidity Hotel_Name
# 7   margaret river      AU -33.9500  115.0667        60
# 30          koster      ZA -25.8630   26.8976        57
# 45    port lincoln      AU -34.7333  135.8667        56
# 51     sangsong-ni      KP  39.1694  126.8856        29
# 77         awjilah      LY  29.1081   21.2869        15

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories": "accommodation.hotel",
          "filter": "",
          "bias" : "", 
          "limit" : 1,
          "apiKey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"  
    params["bias"] = f"proximity:{lng},{lat}" 
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df.head()
# Out:
# Starting hotel search
# margaret river - nearest hotel: Margaret River Hotel
# koster - nearest hotel: No hotel found
# port lincoln - nearest hotel: Boston Hotel
# sangsong-ni - nearest hotel: Hotel 1
# awjilah - nearest hotel: No hotel found
# liman - nearest hotel: Зоря
# pueblo - nearest hotel: Station on the Riverwalk
# marneuli - nearest hotel: Star Hotel
# adrar - nearest hotel: No hotel found
# goundam - nearest hotel: No hotel found
# tshabong - nearest hotel: No hotel found
# ardakan - nearest hotel: هتل رستوران باغ سرای اردکان
# gargalianoi - nearest hotel: Messinian Horizons
# cerda - nearest hotel: Targa Florio, Agriturismo
# tolanaro - nearest hotel: Hôtel Mahavokey
# bovalino - nearest hotel: No hotel found
# constantia - nearest hotel: Hotel Chérica
# hami - nearest hotel: Хами
# la manga del mar menor - nearest hotel: Hotel Entremares
# nafplio - nearest hotel: Ναυπλία
# argostolion - nearest hotel: Ainos Hotel
# benjamin hill - nearest hotel: No hotel found
# kijang - nearest hotel: 힐튼호텔 부산
# copsa mica - nearest hotel: Medieval Apartments Frauendorf
# gorgan - nearest hotel: هتل خیام
# korla - nearest hotel: Silver Star Hotel
# heroica caborca - nearest hotel: Hotel Posada del Desierto
# stawell - nearest hotel: Coorrabin Motor Inn
# aldinga beach - nearest hotel: The Beach Hotel
# sinop - nearest hotel: No hotel found
# port saint john's - nearest hotel: Outback Inn
# wickenburg - nearest hotel: Best Western Rancho Grande
# junction city - nearest hotel: Candlewood Suites
# gharavuti - nearest hotel: No hotel found
# quartu sant'elena - nearest hotel: Hotel Italia
# laizhou - nearest hotel: 新世纪大酒店
# machico - nearest hotel: Residence Inn
# ghanzi - nearest hotel: Ghanzi farmhouse
# raton - nearest hotel: Travelodge
# mhamid - nearest hotel: Hotel Kasbah Azalay
# sandanski - nearest hotel: Хотел Сандански
# shiprock - nearest hotel: No hotel found
# cooma - nearest hotel: Royal Hotel
# broken hill - nearest hotel: Ibis Styles
# ivins - nearest hotel: Crescent Moon Inn
# socorro - nearest hotel: WoodSpring Suites El Paso I-10 Southeast
# durban - nearest hotel: Tudor
# beyneu - nearest hotel: Johan yu
# high rock - nearest hotel: No hotel found
# corinth - nearest hotel: Apollon
# tadmur - nearest hotel: فندق فيلا بالميرا
#               City Country      Lat       Lng  Humidity Hotel_Name  \
# 7   margaret river      AU -33.9500  115.0667        60
# 30          koster      ZA -25.8630   26.8976        57
# 45    port lincoln      AU -34.7333  135.8667        56
# 51     sangsong-ni      KP  39.1694  126.8856        29
# 77         awjilah      LY  29.1081   21.2869        15
#
#               Hotel Name
# 7   Margaret River Hotel
# 30        No hotel found
# 45          Boston Hotel
# 51               Hotel 1
# 77        No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map2 = hotel_df.hvplot.points("Lng", "Lat", geo=True, tiles="OSM", size="Humidity", color="City", hover_cols=["City", "Humidity", "Hotel Name"], frame_height=400, frame_width=600)


# Display the map
map2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name)
