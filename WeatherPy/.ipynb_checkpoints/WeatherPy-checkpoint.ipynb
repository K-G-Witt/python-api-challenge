# Processing Record 45 of Set 3 | goroka
# Processing Record 46 of Set 3 | celestun
# Processing Record 47 of Set 3 | tual
# Processing Record 48 of Set 3 | sotkamo
# Processing Record 49 of Set 3 | dire dawa
# Processing Record 0 of Set 4 | ust-nera
# Processing Record 1 of Set 4 | anton lizardo
# Processing Record 2 of Set 4 | tianpeng
# Processing Record 3 of Set 4 | khorixas
# Processing Record 4 of Set 4 | santa rosalia
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | zeya
# Processing Record 7 of Set 4 | taguatinga
# Processing Record 8 of Set 4 | stanley
# Processing Record 9 of Set 4 | vilyuchinsk
# Processing Record 10 of Set 4 | sola
# Processing Record 11 of Set 4 | kargasok
# Processing Record 12 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 13 of Set 4 | yemetsk
# Processing Record 14 of Set 4 | khajuraho group of monuments
# Processing Record 15 of Set 4 | carnarvon
# Processing Record 16 of Set 4 | tobi village
# City not found. Skipping...
# Processing Record 17 of Set 4 | colombo
# Processing Record 18 of Set 4 | srandakan
# Processing Record 19 of Set 4 | chonchi
# Processing Record 20 of Set 4 | vadso
# Processing Record 21 of Set 4 | sechelt
# Processing Record 22 of Set 4 | al fashn
# Processing Record 23 of Set 4 | happy valley-goose bay
# Processing Record 24 of Set 4 | nieuw amsterdam
# Processing Record 25 of Set 4 | olyokminsk
# Processing Record 26 of Set 4 | utrik
# Processing Record 27 of Set 4 | taltal
# Processing Record 28 of Set 4 | blacksburg
# Processing Record 29 of Set 4 | talnakh
# Processing Record 30 of Set 4 | castillos
# Processing Record 31 of Set 4 | susuman
# Processing Record 32 of Set 4 | krasnaya gorbatka
# Processing Record 33 of Set 4 | tamanrasset
# Processing Record 34 of Set 4 | kuala terengganu
# Processing Record 35 of Set 4 | crane
# Processing Record 36 of Set 4 | ciudad lazaro cardenas
# Processing Record 37 of Set 4 | kingston
# Processing Record 38 of Set 4 | kisi
# Processing Record 39 of Set 4 | xishan
# Processing Record 40 of Set 4 | alaghsas
# Processing Record 41 of Set 4 | richards bay
# Processing Record 42 of Set 4 | pilar
# Processing Record 43 of Set 4 | okhotsk
# Processing Record 44 of Set 4 | guarapari
# Processing Record 45 of Set 4 | iskateley
# Processing Record 46 of Set 4 | cabo san lucas
# Processing Record 47 of Set 4 | shevchenko
# Processing Record 48 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 49 of Set 4 | north shore
# Processing Record 0 of Set 5 | nuku'alofa
# Processing Record 1 of Set 5 | kodiak
# Processing Record 2 of Set 5 | buta
# Processing Record 3 of Set 5 | odienne
# Processing Record 4 of Set 5 | karymskoye
# Processing Record 5 of Set 5 | oliver
# Processing Record 6 of Set 5 | remire-montjoly
# Processing Record 7 of Set 5 | winneba
# Processing Record 8 of Set 5 | padang
# Processing Record 9 of Set 5 | rawson
# Processing Record 10 of Set 5 | sanctuary point
# Processing Record 11 of Set 5 | zorgo
# Processing Record 12 of Set 5 | yeniseysk
# Processing Record 13 of Set 5 | salalah
# Processing Record 14 of Set 5 | inirida
# Processing Record 15 of Set 5 | general villegas
# Processing Record 16 of Set 5 | suva
# Processing Record 17 of Set 5 | holualoa
# Processing Record 18 of Set 5 | ad dilam
# Processing Record 19 of Set 5 | mamuju
# Processing Record 20 of Set 5 | la sarre
# Processing Record 21 of Set 5 | fort bragg
# Processing Record 22 of Set 5 | chiili
# City not found. Skipping...
# Processing Record 23 of Set 5 | batam
# City not found. Skipping...
# Processing Record 24 of Set 5 | center point
# Processing Record 25 of Set 5 | cooper's town
# Processing Record 26 of Set 5 | kaman
# Processing Record 27 of Set 5 | atlantic
# Processing Record 28 of Set 5 | scone
# Processing Record 29 of Set 5 | aktau
# Processing Record 30 of Set 5 | victorica
# Processing Record 31 of Set 5 | kayangel
# Processing Record 32 of Set 5 | derebucak
# Processing Record 33 of Set 5 | isla vista
# Processing Record 34 of Set 5 | fernie
# Processing Record 35 of Set 5 | lagunas
# Processing Record 36 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 37 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 38 of Set 5 | horta
# Processing Record 39 of Set 5 | gisborne
# Processing Record 40 of Set 5 | novofedorivka
# Processing Record 41 of Set 5 | ijuw
# City not found. Skipping...
# Processing Record 42 of Set 5 | kuytun
# Processing Record 43 of Set 5 | khandyga
# Processing Record 44 of Set 5 | eyl
# Processing Record 45 of Set 5 | mokhsogollokh
# Processing Record 46 of Set 5 | comodoro rivadavia
# Processing Record 47 of Set 5 | manokwari
# Processing Record 48 of Set 5 | aasiaat
# Processing Record 49 of Set 5 | saldanha
# Processing Record 0 of Set 6 | queenstown
# Processing Record 1 of Set 6 | labrador city
# Processing Record 2 of Set 6 | wotho
# Processing Record 3 of Set 6 | inarajan village
# Processing Record 4 of Set 6 | ravar
# Processing Record 5 of Set 6 | makoua
# Processing Record 6 of Set 6 | naraini
# Processing Record 7 of Set 6 | broome
# Processing Record 8 of Set 6 | anadyr
# Processing Record 9 of Set 6 | qaqortoq
# Processing Record 10 of Set 6 | damara
# Processing Record 11 of Set 6 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 12 of Set 6 | cidreira
# Processing Record 13 of Set 6 | rantauprapat
# Processing Record 14 of Set 6 | mili
# Processing Record 15 of Set 6 | hami
# Processing Record 16 of Set 6 | daru
# Processing Record 17 of Set 6 | tobelo
# Processing Record 18 of Set 6 | oranjemund
# Processing Record 19 of Set 6 | saynshand
# Processing Record 20 of Set 6 | smara
# Processing Record 21 of Set 6 | cadiz
# Processing Record 22 of Set 6 | el bolson
# Processing Record 23 of Set 6 | puerto ayora
# Processing Record 24 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 6 | linxia chengguanzhen
# Processing Record 26 of Set 6 | taoudenni
# Processing Record 27 of Set 6 | izki
# Processing Record 28 of Set 6 | bodo
# Processing Record 29 of Set 6 | al faw
# Processing Record 30 of Set 6 | hammerfest
# Processing Record 31 of Set 6 | vila velha
# Processing Record 32 of Set 6 | emerald
# Processing Record 33 of Set 6 | pearland
# Processing Record 34 of Set 6 | chuhar jamali
# Processing Record 35 of Set 6 | alice springs
# Processing Record 36 of Set 6 | camana
# Processing Record 37 of Set 6 | sonoita
# Processing Record 38 of Set 6 | zakamensk
# Processing Record 39 of Set 6 | tolanaro
# Processing Record 40 of Set 6 | puerto la cruz
# Processing Record 41 of Set 6 | enewetak
# Processing Record 42 of Set 6 | rikaze
# Processing Record 43 of Set 6 | newman
# Processing Record 44 of Set 6 | archangelos
# Processing Record 45 of Set 6 | sitka
# Processing Record 46 of Set 6 | ontario
# Processing Record 47 of Set 6 | laojunmiao
# Processing Record 48 of Set 6 | huanren
# Processing Record 49 of Set 6 | tubmanburg
# Processing Record 0 of Set 7 | nyurba
# Processing Record 1 of Set 7 | canon city
# Processing Record 2 of Set 7 | keren
# Processing Record 3 of Set 7 | la paz
# Processing Record 4 of Set 7 | toga village
# City not found. Skipping...
# Processing Record 5 of Set 7 | ingeniero jacobacci
# Processing Record 6 of Set 7 | campbell river
# Processing Record 7 of Set 7 | sihanoukville
# Processing Record 8 of Set 7 | ad douiem
# Processing Record 9 of Set 7 | nagqu
# Processing Record 10 of Set 7 | abuyog
# Processing Record 11 of Set 7 | amga
# Processing Record 12 of Set 7 | fonte boa
# Processing Record 13 of Set 7 | n'zeto
# Processing Record 14 of Set 7 | hastings
# Processing Record 15 of Set 7 | monteros
# Processing Record 16 of Set 7 | phalaborwa
# Processing Record 17 of Set 7 | tazovsky
# Processing Record 18 of Set 7 | codrington
# Processing Record 19 of Set 7 | ain beni mathar
# City not found. Skipping...
# Processing Record 20 of Set 7 | labytnangi
# Processing Record 21 of Set 7 | thinadhoo
# Processing Record 22 of Set 7 | sao joao da barra
# Processing Record 23 of Set 7 | zorritos
# Processing Record 24 of Set 7 | ma'an
# Processing Record 25 of Set 7 | uturoa
# Processing Record 26 of Set 7 | itanhaem
# Processing Record 27 of Set 7 | tofol
# Processing Record 28 of Set 7 | fort mcmurray
# Processing Record 29 of Set 7 | kadinhani
# Processing Record 30 of Set 7 | puttalam
# Processing Record 31 of Set 7 | dryden
# Processing Record 32 of Set 7 | kotagiri
# Processing Record 33 of Set 7 | aioun
# Processing Record 34 of Set 7 | amungan
# Processing Record 35 of Set 7 | sinabang
# Processing Record 36 of Set 7 | luderitz
# Processing Record 37 of Set 7 | ilagan
# Processing Record 38 of Set 7 | odiongan
# Processing Record 39 of Set 7 | villablino
# Processing Record 40 of Set 7 | greensboro
# Processing Record 41 of Set 7 | devinuwara
# City not found. Skipping...
# Processing Record 42 of Set 7 | talara
# Processing Record 43 of Set 7 | vulcanesti
# Processing Record 44 of Set 7 | broken hill
# Processing Record 45 of Set 7 | am timan
# Processing Record 46 of Set 7 | mata-utu
# Processing Record 47 of Set 7 | kot malik barkhurdar
# Processing Record 48 of Set 7 | anabar
# City not found. Skipping...
# Processing Record 49 of Set 7 | ta`u
# Processing Record 0 of Set 8 | nova vicosa
# Processing Record 1 of Set 8 | port sudan
# Processing Record 2 of Set 8 | ciudad melchor muzquiz
# Processing Record 3 of Set 8 | jonquiere
# Processing Record 4 of Set 8 | tsiombe
# Processing Record 5 of Set 8 | pyapon
# Processing Record 24 of Set 9 | boromo
# Processing Record 25 of Set 9 | homer
# Processing Record 26 of Set 9 | rurrenabaque
# Processing Record 27 of Set 9 | mossel bay
# Processing Record 28 of Set 9 | millington
# Processing Record 29 of Set 9 | awjilah
# Processing Record 30 of Set 9 | khilok
# Processing Record 31 of Set 9 | gargalianoi
# Processing Record 32 of Set 9 | urangan
# Processing Record 33 of Set 9 | sabang
# Processing Record 34 of Set 9 | yulinshi
# Processing Record 35 of Set 9 | alesund
# Processing Record 36 of Set 9 | hasaki
# Processing Record 37 of Set 9 | kailua-kona
# Processing Record 38 of Set 9 | randfontein
# Processing Record 39 of Set 9 | vilhena
# Processing Record 40 of Set 9 | midvagur
# Processing Record 41 of Set 9 | takoradi
# Processing Record 42 of Set 9 | cockburn town
# Processing Record 43 of Set 9 | essaouira
# Processing Record 44 of Set 9 | wau
# Processing Record 45 of Set 9 | namibe
# Processing Record 46 of Set 9 | san luis ixcan
# Processing Record 47 of Set 9 | malango
# Processing Record 48 of Set 9 | rio grande
# Processing Record 49 of Set 9 | kirensk
# Processing Record 0 of Set 10 | bayan nur
# City not found. Skipping...
# Processing Record 1 of Set 10 | salmon arm
# Processing Record 2 of Set 10 | yugorsk
# Processing Record 3 of Set 10 | soata
# Processing Record 4 of Set 10 | saint croix
# Processing Record 5 of Set 10 | ellsworth
# Processing Record 6 of Set 10 | porto novo
# Processing Record 7 of Set 10 | nevada
# Processing Record 8 of Set 10 | northam
# Processing Record 9 of Set 10 | 'ibri
# City not found. Skipping...
# Processing Record 10 of Set 10 | falmouth
# Processing Record 11 of Set 10 | plastun
# Processing Record 12 of Set 10 | bremervorde
# Processing Record 13 of Set 10 | xining
# Processing Record 14 of Set 10 | nikolayevsk-on-amure
# Processing Record 15 of Set 10 | ipaba
# Processing Record 16 of Set 10 | udachny
# Processing Record 17 of Set 10 | selfoss
# Processing Record 18 of Set 10 | myeik
# Processing Record 19 of Set 10 | lazaro cardenas
# Processing Record 20 of Set 10 | howard springs
# Processing Record 21 of Set 10 | rongelap
# Processing Record 22 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 23 of Set 10 | yelizovo
# Processing Record 24 of Set 10 | banjar
# Processing Record 25 of Set 10 | ulsteinvik
# Processing Record 26 of Set 10 | ghadamis
# Processing Record 27 of Set 10 | pisco
# Processing Record 28 of Set 10 | usol'ye
# Processing Record 29 of Set 10 | arrifes
# Processing Record 30 of Set 10 | bikenibeu village
# Processing Record 31 of Set 10 | forest hills
# Processing Record 32 of Set 10 | taulaga
# Processing Record 33 of Set 10 | leava
# Processing Record 34 of Set 10 | aginskoye
# Processing Record 35 of Set 10 | ouarzazat
# Processing Record 36 of Set 10 | mbaiki
# Processing Record 37 of Set 10 | lianzhou
# Processing Record 38 of Set 10 | la junta
# Processing Record 39 of Set 10 | tartaro
# Processing Record 40 of Set 10 | sao jose da coroa grande
# Processing Record 41 of Set 10 | labis
# Processing Record 42 of Set 10 | xunchang
# Processing Record 43 of Set 10 | bengkulu
# Processing Record 44 of Set 10 | aver-o-mar
# Processing Record 45 of Set 10 | rawai
# Processing Record 46 of Set 10 | ponta delgada
# Processing Record 47 of Set 10 | qamdo
# Processing Record 48 of Set 10 | williams lake
# Processing Record 49 of Set 10 | colonia
# Processing Record 0 of Set 11 | fortaleza
# Processing Record 1 of Set 11 | tarawa
# Processing Record 2 of Set 11 | bozoum
# Processing Record 3 of Set 11 | sisimiut
# Processing Record 4 of Set 11 | tateyama
# Processing Record 5 of Set 11 | palikir - national government center
# Processing Record 6 of Set 11 | necochea
# Processing Record 7 of Set 11 | demopolis
# Processing Record 8 of Set 11 | pishin
# Processing Record 9 of Set 11 | steamboat springs
# Processing Record 10 of Set 11 | harnosand
# Processing Record 11 of Set 11 | san antonio de pale
# Processing Record 12 of Set 11 | goondiwindi
# Processing Record 13 of Set 11 | vorkuta
# Processing Record 14 of Set 11 | timimoun
# Processing Record 15 of Set 11 | piatykhatky
# Processing Record 16 of Set 11 | galle
# Processing Record 17 of Set 11 | pariaman
# Processing Record 18 of Set 11 | winnemucca
# Processing Record 19 of Set 11 | pa daet
# Processing Record 20 of Set 11 | sovetskaya gavan'
# Processing Record 21 of Set 11 | darwin
# Processing Record 22 of Set 11 | xinyuan
# Processing Record 23 of Set 11 | tadine
# Processing Record 24 of Set 11 | katsuura
# Processing Record 25 of Set 11 | gia nghia
# City not found. Skipping...
# Processing Record 26 of Set 11 | kwang binh
# Processing Record 27 of Set 11 | taroa
# Processing Record 28 of Set 11 | sao vicente
# Processing Record 29 of Set 11 | serdar
# Processing Record 30 of Set 11 | bazhovo
# Processing Record 31 of Set 11 | berwick-upon-tweed
# Processing Record 32 of Set 11 | ambon
# Processing Record 33 of Set 11 | waingapu
# Processing Record 34 of Set 11 | kulhudhuffushi
# Processing Record 35 of Set 11 | tara
# Processing Record 36 of Set 11 | buchanan
# Processing Record 37 of Set 11 | kone
# Processing Record 38 of Set 11 | tangalle
# Processing Record 39 of Set 11 | el galpon
# Processing Record 40 of Set 11 | bajina basta
# Processing Record 41 of Set 11 | tabou
# Processing Record 42 of Set 11 | tvoroyri
# Processing Record 43 of Set 11 | al abyar
# Processing Record 44 of Set 11 | mukah
# City not found. Skipping...
# Processing Record 45 of Set 11 | turbat
# Processing Record 46 of Set 11 | muravlenko
# Processing Record 47 of Set 11 | novodvinsk
# Processing Record 48 of Set 11 | sokhumi
# Processing Record 49 of Set 11 | poli
# Processing Record 0 of Set 12 | tazacorte
# Processing Record 1 of Set 12 | tibiri
# Processing Record 2 of Set 12 | akita
# Processing Record 3 of Set 12 | turkestan
# Processing Record 4 of Set 12 | orange
# Processing Record 5 of Set 12 | saint-pierre
# Processing Record 6 of Set 12 | ugoofaaru
# Processing Record 7 of Set 12 | upata
# Processing Record 8 of Set 12 | santa marta de ortigueira
# Processing Record 9 of Set 12 | karratha
# Processing Record 10 of Set 12 | recani
# Processing Record 11 of Set 12 | kiunga
# Processing Record 12 of Set 12 | torghay
# Processing Record 13 of Set 12 | kirakira
# Processing Record 14 of Set 12 | chilpancingo
# Processing Record 15 of Set 12 | pimentel
# Processing Record 16 of Set 12 | juba
# Processing Record 17 of Set 12 | galesong
# Processing Record 18 of Set 12 | sunne
# Processing Record 19 of Set 12 | sima
# Processing Record 20 of Set 12 | trashi yangtse
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          544
# Lat           544
# Lng           544
# Max Temp      544
# Humidity      544
# Cloudiness    544
# Wind Speed    544
# Country       544
# Date          544
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         jamestown  42.0970  -79.2353     14.45        99         100
# 1          hermanus -34.4187   19.2345     12.67        79          44
# 2  flying fish cove -10.4217  105.6791     29.82        74          75
# 3    ribeira grande  38.5167  -28.7000     15.99        94          12
# 4               ola  59.5833  151.2833     -0.48        89          44
#
#    Wind Speed Country        Date
# 0        2.57      US  1712897226
# 1        5.54      ZA  1712896980
# 2        5.66      CX  1712897051
# 3        0.45      PT  1712897227
# 4        0.66      RU  1712897227

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               jamestown  42.0970  -79.2353     14.45        99         100
# 1                hermanus -34.4187   19.2345     12.67        79          44
# 2        flying fish cove -10.4217  105.6791     29.82        74          75
# 3          ribeira grande  38.5167  -28.7000     15.99        94          12
# 4                     ola  59.5833  151.2833     -0.48        89          44
#
#          Wind Speed Country        Date
# City_ID
# 0              2.57      US  1712897226
# 1              5.54      ZA  1712896980
# 2              5.66      CX  1712897051
# 3              0.45      PT  1712897227
# 4              0.66      RU  1712897227

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"],edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(visible=True, which="major", axis="both", linestyle="-", color="lightgrey")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"],edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(visible=True, which="major", axis="both", linestyle="-", color="lightgrey")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"],edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(visible=True, which="major", axis="both", linestyle="-", color="lightgrey")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"],edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(visible=True, which="major", axis="both", linestyle="-", color="lightgrey")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_regress_plots(x_values, y_values, title, ylabel, text_coordinates):
        
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate regression line
    regress_values = x_values * slope + intercept
    
    # Plot data and regression line
    plt.scatter(x_values, y_values, color="blue", edgecolor="black", alpha=0.75)
    plt.plot(x_values, regress_values, color="red")
    
    # Annotate regression equation
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    
    # Set labels and title
    plt.xlabel("Latitude")
    plt.ylabel(ylabel)
    plt.title(title)
    
    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             jamestown  42.0970  -79.2353     14.45        99         100
# 3        ribeira grande  38.5167  -28.7000     15.99        94          12
# 4                   ola  59.5833  151.2833     -0.48        89          44
# 5                iwanai  42.9744  140.5089     15.49        50          99
# 10                 nuuk  64.1835  -51.7216     -3.66        80          20
#
#          Wind Speed Country        Date
# City_ID
# 0              2.57      US  1712897226
# 3              0.45      PT  1712897227
# 4              0.66      RU  1712897227
# 5              1.13      JP  1712897207
# 10             2.57      GL  1712897229

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                 hermanus -34.4187   19.2345     12.67        79          44
# 2         flying fish cove -10.4217  105.6791     29.82        74          75
# 6                adamstown -25.0660 -130.1015     21.73        52          43
# 7        port-aux-francais -49.3500   70.2167      6.25        89          99
# 8                  ushuaia -54.8000  -68.3000      8.81        71          20
#
#          Wind Speed Country        Date
# City_ID
# 1              5.54      ZA  1712896980
# 2              5.66      CX  1712897051
# 6              5.06      PN  1712897228
# 7              7.95      TF  1712896973
# 8              9.26      AR  1712897228

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
lin_regress_plots(x_values, y_values, "Temperature vs. Latitude Linear Regression Plot", "Temperature (C)", (min(x_values) + 40, min(y_values) + 60))

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
lin_regress_plots(x_values, y_values, "Temperature vs. Latitude Linear Regression Plot", "Temperature (C)", (min(x_values) + 30, min(y_values) + 1))

# %% [markdown]
# **Discussion about the linear relationship:**
#
# For Northern Hemisphere cities there is a negative association between latitude and temperature in degrees Celsius. In other words, as you move away from the equator (higher latitudes), maximum daily temperatures tend to decrease. Specifically, the regression equation indicates that, for each 1 unit increase in latitude, there is, on average, a 0.54 decrease in maximum daily temperature measured in degrees Celsius.
#
# For Southern Hemisphere cities the reverse is true. In order words, as you move closer to the equator (latitudes closer to 0), maximum daily tempreatures tend to increase as latitude increases. Specifically, the regression equation indicates that, for each 1 unit increase in latitude, there is, on average, a 0.42 increase in maximum daily temperature measured in degrees Celsius.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
lin_regress_plots(x_values, y_values, "Humidity vs. Latitude Linear Regression Plot", "Humidity (%)", (min(x_values) + 50, min(y_values) + 5))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
lin_regress_plots(x_values, y_values, "Humidity vs. Latitude Linear Regression Plot", "Humidity (%)", (min(x_values) + 40, min(y_values) + 5))

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Compared with the relationship between latitude and maximum daily temperature (measured in degrees Celisus), the relationship between latitude and humidity (%) is not as significant.
#
# For both Northern and Southern Hemisphere cities, there is a slight positive association between latitude and humidity (%). For Northern Hemisphere cities, for each 1 unit increase in latitude there is, on average, a 0.28 increase in humidity. For Southern Hemisphere locations, for each 1 unit increase in latitude there is, on average, a 0.26 increase in humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
lin_regress_plots(x_values, y_values, "Cloudiness vs. Latitude Linear Regression Plot", "Cloudiness (%)", (min(x_values) + 50, min(y_values) + 5))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
lin_regress_plots(x_values, y_values, "Cloudiness vs. Latitude Linear Regression Plot", "Cloudiness (%)", (min(x_values) + 30, min(y_values) + 5))

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Compared with the relationship between latitude and maximum daily temperature (measured in degrees Celisus), the relationship between latitude and cloudiness (%) is not as significant.
#
# For both Northern and Southern Hemisphere cities, there is a slight positive association between latitude and cloudiness (%). For Northern Hemisphere cities, for each 1 unit increase in latitude there is, on average, a 0.25 increase in cloudiness. For Southern Hemisphere locations, for each 1 unit increase in latitude there is, on average, a 0.38 increase in cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
lin_regress_plots(x_values, y_values, "Wind Speed (m/s) vs. Latitude Linear Regression Plot", "Wind Speed (m/s)", (min(x_values) + 1, min(y_values) + 15))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
lin_regress_plots(x_values, y_values, "Wind Speed (m/s) vs. Latitude Linear Regression Plot", "Wind Speed (m/s)", (min(x_values) + 1, min(y_values) + 11))

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Compared with the relationship between latitude and maximum daily temperature (measured in degrees Celisus), the relationship between latitude and wind speed (m/s) is not as significant.
#
# For Northern Hemisphere cities, there is a slight positive association between latitude and wind speed (m/s). For each 1 unit increase in latitude there is, on average, a 0.02 increase in wind speed (m/s). For Southern Hemisphere locations, the reverse is true and a sligh negative association between latitude and wind speed (m/s) is evident. For each 1 unit increase in latitude there is, on average, a 0.04 decrease in wind speed (m/s).
